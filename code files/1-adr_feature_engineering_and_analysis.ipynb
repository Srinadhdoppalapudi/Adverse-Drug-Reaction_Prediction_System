# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
drug_names = pd.read_csv('../drug_names.tsv',
                         sep='\t',
                         header=None,
                         names=['STITCH_ID', 'Drug_Name'])

# %%
drug_names.head()
# Out:
#       STITCH_ID                 Drug_Name
# 0  CID100000085                 carnitine
# 1  CID100000119        gamma-aminobutyric
# 2  CID100000137          5-aminolevulinic
# 3  CID100000143                leucovorin
# 4  CID100000146  5-methyltetrahydrofolate

# %%
drug_names.isna().sum()
# Out:
# STITCH_ID    0
# Drug_Name    0
# dtype: int64

# %%
indications = pd.read_csv('../meddra_all_indications.tsv',
                          sep='\t',
                          header=None,
                          names=['STITCH_ID', 'UMLS_ID', 'Detection_Method',
                                 'Indication_Name', 'MedDRA_Type',
                                 'UMLS_ID2', 'MedDRA_Indication_Name'])

indications.columns = indications.columns.str.lower()

indications.head()
# Out:
#       stitch_id   umls_id detection_method          indication_name  \
# 0  CID100000085  C0015544     text_mention        Failure to Thrive
# 1  CID100000085  C0015544     text_mention        Failure to Thrive
# 2  CID100000085  C0020615     text_mention             Hypoglycemia
# 3  CID100000085  C0020615     text_mention             Hypoglycemia
# 4  CID100000085  C0022661   NLP_indication  Kidney Failure, Chronic
#
#   meddra_type  umls_id2 meddra_indication_name
# 0         LLT  C0015544      Failure to thrive
# 1          PT  C0015544      Failure to thrive
# 2         LLT  C0020615          Hypoglycaemia
# 3          PT  C0020615          Hypoglycaemia
# 4         LLT  C0022661  Renal failure chronic

# %%
indications.value_counts()
# Out:
# stitch_id     umls_id   detection_method  indication_name                   meddra_type  umls_id2  meddra_indication_name
# CID100000085  C0015544  text_mention      Failure to Thrive                 LLT          C0015544  Failure to thrive                   1
#                                                                             PT           C0015544  Failure to thrive                   1
#               C0020615  text_mention      Hypoglycemia                      LLT          C0020615  Hypoglycaemia                       1
#                                                                             PT           C0020615  Hypoglycaemia                       1
#               C0022661  NLP_indication    Kidney Failure, Chronic           LLT          C0022661  Renal failure chronic               1
#                                                                                                                                       ..
# CID171306834  C0524910  NLP_precondition  Hepatitis C, Chronic              PT           C0524910  Chronic hepatitis C                 1
#               C0741132  text_mention      Antibody test positive            LLT          C0741132  Antibody test positive              1
#                                                                             PT           C0741132  Antibody test positive              1
#               C0856536  text_mention      Philadelphia chromosome positive  LLT          C0856536  Philadelphia chromosome positive    1
#                                                                             PT           C0476431  Chromosome analysis abnormal        1
# Name: count, Length: 30794, dtype: int64

# %%
indications.isna().sum()
# Out:
# stitch_id                  0
# umls_id                    0
# detection_method           0
# indication_name            0
# meddra_type               41
# umls_id2                  41
# meddra_indication_name     0
# dtype: int64

# %%
print(indications.columns)
print(drug_names.columns)
# Out:
# Index(['stitch_id', 'umls_id', 'detection_method', 'indication_name',
#        'meddra_type', 'umls_id2', 'meddra_indication_name'],
#       dtype='str')
# Index(['STITCH_ID', 'Drug_Name'], dtype='str')

# %%
# Clean column names in both dataframes
indications.columns = indications.columns.str.lower().str.strip()
drug_names.columns = drug_names.columns.str.lower().str.strip()

# Merge on stitch_id
merged_indications = pd.merge(
    indications,
    drug_names,
    on="stitch_id",
    how="left"
)

# Remove duplicates
merged_indications = merged_indications.drop_duplicates()

# Remove rows where drug_name is missing (important)
merged_indications = merged_indications.dropna(subset=["drug_name"])

# View result
merged_indications.head()
# Out:
#       stitch_id   umls_id detection_method          indication_name  \
# 0  CID100000085  C0015544     text_mention        Failure to Thrive
# 1  CID100000085  C0015544     text_mention        Failure to Thrive
# 2  CID100000085  C0020615     text_mention             Hypoglycemia
# 3  CID100000085  C0020615     text_mention             Hypoglycemia
# 4  CID100000085  C0022661   NLP_indication  Kidney Failure, Chronic
#
#   meddra_type  umls_id2 meddra_indication_name  drug_name
# 0         LLT  C0015544      Failure to thrive  carnitine
# 1          PT  C0015544      Failure to thrive  carnitine
# 2         LLT  C0020615          Hypoglycaemia  carnitine
# 3          PT  C0020615          Hypoglycaemia  carnitine
# 4         LLT  C0022661  Renal failure chronic  carnitine

# %%
side_effects = pd.read_csv(
    '../meddra_all_se.tsv',
    sep='\t',
    header=None,
    names=[
        'stitch_id_flat',
        'stitch_id_stereo',
        'umls_id',
        'concept_type',
        'meddra_umls_id',
        'side_effect_name'
    ]
)

side_effects.columns = side_effects.columns.str.lower().str.strip()

side_effects.head()
# Out:
#   stitch_id_flat stitch_id_stereo   umls_id concept_type meddra_umls_id  \
# 0   CID100000085     CID000010917  C0000729          LLT       C0000729
# 1   CID100000085     CID000010917  C0000729           PT       C0000737
# 2   CID100000085     CID000010917  C0000737          LLT       C0000737
# 3   CID100000085     CID000010917  C0000737           PT       C0687713
# 4   CID100000085     CID000010917  C0000737           PT       C0000737
#
#         side_effect_name
# 0       Abdominal cramps
# 1         Abdominal pain
# 2         Abdominal pain
# 3  Gastrointestinal pain
# 4         Abdominal pain

# %%
merged_se = pd.merge(side_effects, drug_names, left_on="stitch_id_flat",right_on='stitch_id',how="left")
merged_se.drop_duplicates(inplace=True)
merged_se.dropna(inplace=True)
merged_se.drop(columns=['stitch_id'],inplace=True)
merged_se.head()
# Out:
#   stitch_id_flat stitch_id_stereo   umls_id concept_type meddra_umls_id  \
# 0   CID100000085     CID000010917  C0000729          LLT       C0000729
# 1   CID100000085     CID000010917  C0000729           PT       C0000737
# 2   CID100000085     CID000010917  C0000737          LLT       C0000737
# 3   CID100000085     CID000010917  C0000737           PT       C0687713
# 4   CID100000085     CID000010917  C0000737           PT       C0000737
#
#         side_effect_name  drug_name
# 0       Abdominal cramps  carnitine
# 1         Abdominal pain  carnitine
# 2         Abdominal pain  carnitine
# 3  Gastrointestinal pain  carnitine
# 4         Abdominal pain  carnitine

# %%
merged_se.shape
# Out:
# (308948, 7)

# %%
print(f'Merged_indications size={merged_indications.shape}')
print(f'Merged_se size={merged_se.shape}')
# Out:
# Merged_indications size=(30517, 8)
# Merged_se size=(308948, 7)

# %%
df = pd.merge(merged_se, merged_indications, left_on='stitch_id_flat', right_on='stitch_id', how='inner', suffixes=('_se', '_ind'))
df.drop(columns=['stitch_id'], inplace=True)

df.head()
# Out:
#   stitch_id_flat stitch_id_stereo umls_id_se concept_type meddra_umls_id  \
# 0   CID100000085     CID000010917   C0000729          LLT       C0000729
# 1   CID100000085     CID000010917   C0000729          LLT       C0000729
# 2   CID100000085     CID000010917   C0000729          LLT       C0000729
# 3   CID100000085     CID000010917   C0000729          LLT       C0000729
# 4   CID100000085     CID000010917   C0000729          LLT       C0000729
#
#    side_effect_name drug_name_se umls_id_ind detection_method  \
# 0  Abdominal cramps    carnitine    C0015544     text_mention
# 1  Abdominal cramps    carnitine    C0015544     text_mention
# 2  Abdominal cramps    carnitine    C0020615     text_mention
# 3  Abdominal cramps    carnitine    C0020615     text_mention
# 4  Abdominal cramps    carnitine    C0022661   NLP_indication
#
#            indication_name meddra_type  umls_id2 meddra_indication_name  \
# 0        Failure to Thrive         LLT  C0015544      Failure to thrive
# 1        Failure to Thrive          PT  C0015544      Failure to thrive
# 2             Hypoglycemia         LLT  C0020615          Hypoglycaemia
# 3             Hypoglycemia          PT  C0020615          Hypoglycaemia
# 4  Kidney Failure, Chronic         LLT  C0022661  Renal failure chronic
#
#   drug_name_ind
# 0     carnitine
# 1     carnitine
# 2     carnitine
# 3     carnitine
# 4     carnitine

# %%
df.shape
# Out:
# (10481640, 14)

# %%
# Calculate the percentage of rows where 'umls_id_se' and 'meddra_umls_id' are the same
similarity_percentage = (df['umls_id_se'] == df['meddra_umls_id']).median() * 100

print(f"Percentage of exact matches: {similarity_percentage:.2f}%")
# Out:
# Percentage of exact matches: 100.00%

# %%
df.drop(columns=[
    "stitch_id_stereo", "meddra_umls_id", "drug_name_se",
    "umls_id_ind", "detection_method", "indication_name"
], inplace=True)

# Rename `drug_name_ind` to just `drug_name` for clarity
df.rename(columns={"drug_name_ind": "drug_name"}, inplace=True)

df.rename(columns={"drugname_se": "drug_name"}, inplace=True)
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (9312040, 8)

# %%
df.rename(columns={'meddra_indication_name':'indication_name'},inplace=True)

# %%
df.head()
# Out:
#   stitch_id_flat umls_id_se concept_type  side_effect_name meddra_type  \
# 0   CID100000085   C0000729          LLT  Abdominal cramps         LLT
# 1   CID100000085   C0000729          LLT  Abdominal cramps          PT
# 2   CID100000085   C0000729          LLT  Abdominal cramps         LLT
# 3   CID100000085   C0000729          LLT  Abdominal cramps          PT
# 4   CID100000085   C0000729          LLT  Abdominal cramps         LLT
#
#    umls_id2        indication_name  drug_name
# 0  C0015544      Failure to thrive  carnitine
# 1  C0015544      Failure to thrive  carnitine
# 2  C0020615          Hypoglycaemia  carnitine
# 3  C0020615          Hypoglycaemia  carnitine
# 4  C0022661  Renal failure chronic  carnitine

# %%
df.to_csv('merged_data.csv',index=False)

# %%
df['drug_name'].value_counts()
# Out:
# drug_name
# citalopram         193614
# dexamethasone      180220
# paroxetine         179014
# fluoxetine         147898
# triamcinolone      139930
#                     ...
# hexachlorophene        12
# mepyramine             12
# sulfonamide             8
# pertechnetate           8
# triclosan               4
# Name: count, Length: 1284, dtype: int64

# %%
df['indication_name'].value_counts()
# Out:
# indication_name
# Renal impairment        98656
# Infection               89045
# Neoplasm malignant      76040
# Hypertension            69070
# Renal failure           59810
#                         ...
# Low pH                      8
# Blood pH decreased          8
# Blood zinc decreased        5
# Dry scalp                   4
# Nettle rash                 2
# Name: count, Length: 3043, dtype: int64

# %%
duplicate_counts = df.duplicated(keep=False).sum()

print(f"Total number of duplicate rows: {duplicate_counts}")


duplicate_rows_counts = df[df.duplicated(keep=False)].groupby(df.columns.tolist()).size().reset_index(name='count')

print("\nCounts of individual duplicated rows:")
print(duplicate_rows_counts)
# Out:
# Total number of duplicate rows: 0
#
# Counts of individual duplicated rows:
# Empty DataFrame
# Columns: [stitch_id_flat, umls_id_se, concept_type, side_effect_name, meddra_type, umls_id2, indication_name, drug_name, count]
# Index: []

# %% [markdown]
# # EDA

# %%
df.describe(include='all')
# Out:
#        stitch_id_flat umls_id_se concept_type side_effect_name meddra_type  \
# count         9312040    9312040      9312040          9312040     9312040
# unique           1360       5752            2             6007           2
# top      CID100002771   C0231218           PT        Dizziness          PT
# freq           193614      75995      4915754            66485     4710469
#
#         umls_id2   indication_name   drug_name
# count    9312040           9312040     9312040
# unique      3043              3043        1284
# top     C1565489  Renal impairment  citalopram
# freq       98656             98656      193614

# %%
pair_counts=df.groupby(['side_effect_name','indication_name']).size().reset_index(name='count')
pair_counts=pair_counts.sort_values(by='count',ascending=False)
pair_counts.head(30)
# Out:
#                    side_effect_name   indication_name  count
# 1036479                        Rash         Infection    760
# 841857                       Nausea         Infection    742
# 354050                    Dizziness      Hypertension    731
# 336952                    Diarrhoea         Infection    730
# 1300228                    Vomiting         Infection    704
# 354139                    Dizziness         Infection    698
# 355015                    Dizziness  Renal impairment    686
# 551999                     Headache         Infection    638
# 7600                 Abdominal pain         Infection    622
# 1012232                    Pruritus         Infection    614
# 114415                     Asthenia      Hypertension    614
# 842764                       Nausea  Renal impairment    606
# 608858             Hypersensitivity         Infection    604
# 1255757                   Urticaria         Infection    598
# 64224            Anaphylactic shock         Infection    598
# 1037374                        Rash  Renal impairment    592
# 171106   Body temperature increased         Infection    588
# 115345                     Asthenia  Renal impairment    586
# 1301102                    Vomiting  Renal impairment    582
# 434089          Erythema multiforme         Infection    565
# 337802                    Diarrhoea  Renal impairment    563
# 114502                     Asthenia         Infection    552
# 552881                     Headache  Renal impairment    536
# 1013091                    Pruritus  Renal impairment    532
# 171922   Body temperature increased  Renal impairment    524
# 1192413            Thrombocytopenia         Infection    522
# 841765                       Nausea      Hypertension    516
# 8405                 Abdominal pain  Renal impairment    515
# 609716             Hypersensitivity  Renal impairment    513
# 551909                     Headache      Hypertension    510

# %%
# Find all drugs where the same drug name appears with a strange (side effect, indication) pair
drug_mismatch = df.groupby(["drug_name", "side_effect_name", "indication_name"]).size().reset_index(name="count")
drug_mismatch=drug_mismatch.sort_values(by='count',ascending=False)

print(drug_mismatch.head(30))
# Out:
#            drug_name  side_effect_name                    indication_name  \
# 1385140  fluticasone  Nasal discomfort                   Seasonal allergy
# 1385137  fluticasone  Nasal discomfort                 Rhinitis perennial
# 1385136  fluticasone  Nasal discomfort                  Rhinitis allergic
# 714428   clindamycin    Abdominal pain        Respiratory tract infection
# 2643035       sodium         Dizziness                           Headache
# 714446   clindamycin    Abdominal pain                     Vulvovaginitis
# 714441   clindamycin    Abdominal pain                  Vaginal discharge
# 714382   clindamycin    Abdominal pain                  Abdominal abscess
# 714383   clindamycin    Abdominal pain                Abdominal infection
# 714395   clindamycin    Abdominal pain                          Diarrhoea
# 714439   clindamycin    Abdominal pain               Tubo-ovarian abscess
# 714435   clindamycin    Abdominal pain              Soft tissue infection
# 714425   clindamycin    Abdominal pain           Pseudomembranous colitis
# 2643092       sodium         Dizziness                           Vomiting
# 714424   clindamycin    Abdominal pain                          Pneumonia
# 714396   clindamycin    Abdominal pain             Diarrhoea haemorrhagic
# 714420   clindamycin    Abdominal pain                        Peritonitis
# 714415   clindamycin    Abdominal pain                       Parametritis
# 714411   clindamycin    Abdominal pain                      Osteomyelitis
# 714397   clindamycin    Abdominal pain                            Empyema
# 714399   clindamycin    Abdominal pain                       Endometritis
# 714409   clindamycin    Abdominal pain                       Lung abscess
# 714405   clindamycin    Abdominal pain                     Herpes simplex
# 714407   clindamycin    Abdominal pain                          Infection
# 2643063       sodium         Dizziness                             Nausea
# 714408   clindamycin    Abdominal pain  Lower respiratory tract infection
# 714445   clindamycin    Abdominal pain              Vaginitis gardnerella
# 714443   clindamycin    Abdominal pain               Vaginal inflammation
# 714444   clindamycin    Abdominal pain                Vaginitis bacterial
# 1701497      lithium            Tremor                 Pressure of speech
#
#          count
# 1385140     26
# 1385137     26
# 1385136     26
# 714428      20
# 2643035     20
# 714446      20
# 714441      20
# 714382      20
# 714383      20
# 714395      20
# 714439      20
# 714435      20
# 714425      20
# 2643092     20
# 714424      20
# 714396      20
# 714420      20
# 714415      20
# 714411      20
# 714397      20
# 714399      20
# 714409      20
# 714405      20
# 714407      20
# 2643063     20
# 714408      20
# 714445      20
# 714443      20
# 714444      20
# 1701497     18

# %%
# Count unique side effects and indications per drug
drug_check = df.groupby("drug_name").agg(
    num_side_effects=("side_effect_name", "nunique"),
    num_indications=("indication_name", "nunique")
)

# Sort by the highest number of SEs and indications
drug_check = drug_check.sort_values(by=["num_side_effects", "num_indications"], ascending=False)

# Display drugs with unusually high numbers
print(drug_check.head(30))
# Out:
#                num_side_effects  num_indications
# drug_name
# pregabalin                  839               12
# aripiprazole                827               23
# citalopram                  823               74
# ropinirole                  682               18
# risperidone                 666               46
# pramipexole                 648                3
# tramadol                    625                8
# paroxetine                  624               99
# bortezomib                  618                9
# venlafaxine                 584               66
# tacrolimus                  568               47
# fluoxetine                  549               92
# K779                        537               53
# topiramate                  535               31
# fentanyl                    521               47
# gabapentin                  521               25
# bupropion                   520               30
# doxorubicin                 517               80
# ciprofloxacin               512               71
# lenalidomide                502               11
# ofloxacin                   490               64
# mycophenolate               488                5
# capecitabine                483               12
# olanzapine                  476               23
# rivastigmine                468                8
# posaconazole                458               27
# fluvoxamine                 458               21
# retinoic                    453               45
# ribavirin                   449               29
# estradiol                   446               83

# %%
plt.figure(figsize=(10,10))
plt.barh(df['side_effect_name'].value_counts().sort_values(ascending=False)[:50].index, df['side_effect_name'].value_counts().sort_values(ascending=False)[:50].values
       ,color='red', )
plt.xlabel('Count')
plt.ylabel('Side Effect Name')
plt.title('Top 50 Side Effect Names')
plt.tight_layout()
plt.show()

# %%
df['indication_name'].value_counts().head(30).plot(kind='barh',xlabel='Count',
                                               ylabel='Indication Name',title='Top 30 Indication Names')
plt.figure(figsize=(10,10))
plt.show()

# %%
# Count number of side effects per drug
se_per_drug = df.groupby("drug_name")["side_effect_name"].nunique().sort_values(ascending=False)

# Top 10 drugs with most SEs
print(se_per_drug.head(10))

# Visualizing
se_per_drug.head(20).plot(kind='bar', figsize=(12,5), color='orange')
plt.title("Top 20 Drugs with Most Side Effects")
plt.ylabel("Number of Side Effects")
plt.xlabel("Drug Name")
plt.xticks(rotation=75)
plt.show()

print(f'Drugs with lease side effects: {se_per_drug.tail(10)}')
# Out:
# drug_name
# pregabalin      839
# aripiprazole    827
# citalopram      823
# ropinirole      682
# risperidone     666
# pramipexole     648
# tramadol        625
# paroxetine      624
# bortezomib      618
# venlafaxine     584
# Name: side_effect_name, dtype: int64
# Drugs with lease side effects: drug_name
# zinc             3
# crotamiton       3
# ZnCl2            3
# pertechnetate    2
# sulfonamide      2
# DMSO             2
# retinol          2
# selenium         2
# mepyramine       1
# triclosan        1
# Name: side_effect_name, dtype: int64

# %%
# Count number of indications per drug
ind_per_drug = df.groupby("drug_name")["indication_name"].nunique().sort_values(ascending=False)

# Top 10 drugs with most indications
print(ind_per_drug.head(10))

# Visualizing
ind_per_drug.head(20).plot(kind='bar', figsize=(12,5), color='green')
plt.title("Top 20 Drugs with Most Indications")
plt.ylabel("Number of Indications")
plt.xlabel("Drug Name")
plt.xticks(rotation=75)
plt.show()
# Out:
# drug_name
# dexamethasone         199
# prednisolone          147
# methylprednisolone    147
# prednisone            140
# cortisol              140
# demethyl              113
# sodium                112
# triamcinolone         104
# progesterone          100
# paroxetine             99
# Name: indication_name, dtype: int64

# %%
df_indic=df.groupby('drug_name').agg(side_effect_name=('side_effect_name','nunique'),
                                     indication_name=('indication_name','nunique'))

sns.scatterplot(data=df_indic,x='side_effect_name',y='indication_name')
plt.title('Side Effects vs Indications')
plt.xlabel('Number of Side Effects')
plt.ylabel('Number of Indications per drug')
plt.show()
